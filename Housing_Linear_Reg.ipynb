# %% [markdown]
# # Load Data

# %%
import pandas as pd

# %%
cali_dataset = pd.read_csv("California_Houses.csv")

# %%
cali_dataset
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms
# 0                452600.0         8.3252          41        880           129  \
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %% [markdown]
# - medv will be the y-variable(target)
# - everything else is the x-variables(features)

# %% [markdown]
# # Data Split

# %%
Y = cali_dataset.Median_House_Value
Y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: Median_House_Value, Length: 20640, dtype: float64

# %% [markdown]
# - separate variable from features

# %%
X = cali_dataset.drop(['Median_House_Value'], axis=1)
X
# Out:
#        Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  Population
# 0             8.3252          41        880           129         322  \
# 1             8.3014          21       7099          1106        2401
# 2             7.2574          52       1467           190         496
# 3             5.6431          52       1274           235         558
# 4             3.8462          52       1627           280         565
# ...              ...         ...        ...           ...         ...
# 20635         1.5603          25       1665           374         845
# 20636         2.5568          18        697           150         356
# 20637         1.7000          17       2254           485        1007
# 20638         1.8672          18       1860           409         741
# 20639         2.3886          16       2785           616        1387
#
#        Households  Latitude  Longitude  Distance_to_coast  Distance_to_LA
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# - data will be split 80/20
# - 80 percent goes to training the data
# - 20 percent goes for the testing data that will be used to make the prediction

# %%
X_train.shape, Y_train.shape
# Out:
# ((16512, 13), (16512,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((4128, 13), (4128,))

# %% [markdown]
# # Building and using Linear Regression Model

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#        Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  Population
# 9103          3.8594          10       2907           559        1681  \
# 16991         6.1228          17       4199           629        2020
# 19885         2.6065          18       1666           294         859
# 14046         2.8281          30       2582           650        1098
# 18121         6.6766          26       1391           241         700
# ...              ...         ...        ...           ...         ...
# 19964         2.9145          21       2645           464        1245
# 3204          4.2396           4       1684           343         920
# 18653         3.6619          31       3209           723        1489
# 10072         0.9283          10        614           141         195
# 11027         3.8681          31       2016           409        1095
#
#        Households  Latitude  Longitude  Distance_to_coast  Distance_to_LA
# ...

# %%
Y_pred = model.predict(X_test)
#creates predictions for house prices based off of our test data

# %%
Y_test
# Out:
# 9103     141000.0
# 16991    375700.0
# 19885     93800.0
# 14046    171700.0
# 18121    332700.0
#            ...
# 19964    114200.0
# 3204      90600.0
# 18653    245100.0
# 10072    116300.0
# 11027    196000.0
# Name: Median_House_Value, Length: 4128, dtype: float64

# %%
Y_pred
# Out:
# array([163424.83070532, 301118.44745826,  69393.42257429, ...,
#        256733.50337905, -60885.82231709, 214962.82914337])

# %%
print('Intercept:', model.intercept_)
print('MSE: %.2f'% mean_squared_error(Y_test, Y_pred))
print('R2 Score: %.2f'% r2_score(Y_test, Y_pred))
#ytest is actual value
#ypred is predicted value
# Out:
# Intercept: -1810838.2471761215
# MSE: 4841329145.11
# R2 Score: 0.65

# %%
cali_dataset.head()
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms
# 0            452600.0         8.3252          41        880           129  \
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast
# 0         322         126     37.88    -122.23        9263.040773  \
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose
# ...

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.6451669695170268

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
ax = sns.scatterplot(x=Y_test, y=Y_pred, alpha=0.2, edgecolor='black')
ax.set(xlabel='Testing target values', ylabel='Predicted target values')
ax.set_title('Predicted values vs. Actual values')
# Out:
# Text(0.5, 1.0, 'Predicted values vs. Actual values')

# %%
sns.regplot(x='Median_Income', y='Median_House_Value', data=cali_dataset)
plt.show()
